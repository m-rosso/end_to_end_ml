# %% [markdown]
# ## End-to-end machine learning application
# ## Deployment - Production model

# %% [markdown]
# This project aims to integrate different aspects of a machine learning system, thus developing an end-to-end ML project. The final product is an app (hypothetically called *AppSafe*) composed of a model that calculates the risk of a mobile app being a malware and an API that could integrate with an app store and with the user by sending him/her a warning message when the mobile app that is about to be downloaded is too risky.
#
# The project follows the traditional [CRISP-DM](https://pt.wikipedia.org/wiki/Cross_Industry_Standard_Process_for_Data_Mining) methodology, so these are the main stages that make the core of the project: data engineering, data preparation, data modeling, and deployment.

# %% [markdown]
# -----------

# %% [markdown]
# This notebook imports all artifacts generated during final training of data modeling stage (notebook "Data Modeling - Final Training"). Next, it creates an object of *Model* class, whose *predict* method is able to produce a prediction for an input data point by applying all necessary operations of data preparation, using an object of *Pipeline* class, and then, making use of an object of *Ensemble* class, the model object finally returns a prediction.
#
# After creating an object of *Model* class, this notebook saves it in a pickle file so it can be used within an application through an API hosted in a local/remote server. This notebook also applies tests over the model object, which helps with the estimation of latency time and with the development of errors handling.

# %% [markdown]
# **Summary:**
# 1. [Libraries](#libraries)<a href='#libraries'></a>.
# 2. [Functions and classes](#functions_classes)<a href='#functions_classes'></a>.
# 3. [Settings](#settings)<a href='#settings'></a>.
# 4. [Importing artifacts](#imports)<a href='#imports'></a>.
#   * [Training data](#training_data)<a href='#training_data'></a>.
#   * [Data understanding](#data_und)<a href='#data_und'></a>.
#   * [Model registry](#model_registry)<a href='#model_registry'></a>.
#   * [Artifacts of the model](#artifacts)<a href='#artifacts'></a>.
#
# 5. [Model in production](#production_model)<a href='#production_model'></a>.
#   * [Sample data](#sample_data)<a href='#sample_data'></a>.
#   * [Model object](#model)<a href='#model'></a>.
#   * [Predictions from the trained model](#predictions)<a href='#predictions'></a>.

# %% [markdown]
# <a id='libraries'></a>

# %% [markdown]
# ## Libraries

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd "/content/gdrive/MyDrive/Studies/end_to_end_ml/notebooks/"
# Out:
# /content/gdrive/MyDrive/Studies/end_to_end_ml/model_dev

# %%
# !pip install -r ../requirements.txt

# %%
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime
import time
import pickle
from copy import deepcopy

# %%
import sys

sys.path.append(
    os.path.abspath(
        os.path.join(
            os.path.dirname(__doc__), '../src'
        )
    )
)

# %% [markdown]
# <a id='functions_classes'></a>

# %% [markdown]
# ## Functions and classes

# %%
from production import Model
from data_vis import plot_histogram

# %% [markdown]
# <a id='settings'></a>

# %% [markdown]
# ## Settings

# %% [markdown]
# <a id='data_management_settings'></a>

# %% [markdown]
# ### Data management

# %%
# Declare whether outcomes should be exported:
EXPORT = False

# Experiment description:
COMMENT = ''

# %% [markdown]
# <a id='imports'></a>

# %% [markdown]
# ## Importing artifacts

# %% [markdown]
# <a id='training_data'></a>

# %% [markdown]
# ### Training data

# %%
df_train = pd.read_csv('../artifacts/df_train.csv', dtype={'app_id': int})

print(f'Shape of df_train: {df_train.shape}.')
print(f'Number of unique instances: {df_train.app_id.nunique()}.')

df_train.head(3)
# Out:
# Shape of df_train: (18298, 61).
# Number of unique instances: 18298.
#                               app                    package  \
# 0  Ambient Soothing Sounds: Beach     com.zeddev.chillbeach1
# 1                          Aurora      jiang.joyworks.aurora
# 2                   Tank Ace 1944  com.resetgame.tankace1944
#
#            category                                        description  \
# 0  Health & Fitness  The soothing sounds on a long and seamless loo...
# 1    Brain & Puzzle  This is one great &quot;Escape Game&quot; <p>Y...
# 2   Arcade & Action  In Tank Ace 1944 you command a World War II ta...
#
#    rating  number_of_ratings  price  \
# 0     3.6                122   0.00
# 1     3.8                 24   1.41
# 2     3.7                 20   4.99
#
#                                         related_apps  \
# 0  com.zeddev.chillmeadow1, com.droiddevz.ambient...
# 1  com.firemaplegames.games.the_secretofgrislyman...
# 2  ru.sibteam.classictankfull, nl.ejsoft.mortalsk...
#
#    dangerous_permissions_count  safe_permissions_count  ...  \
# 0                          1.0                       1  ...
# 1                          1.0                       0  ...
# 2                          0.0                       0  ...
#
#    your_personal_information_write_browsers_history_and_bookmarks  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    your_personal_information_write_contact_data  class  app_id  \
# 0                                             0      0    6565
# 1                                             0      1    4772
# 2                                             0      1   20856
#
#    num_related_apps  num_words_desc  num_known_apps  share_known  \
# 0               4.0            42.0             0.0          0.0
# 1               4.0           251.0             0.0          0.0
# 2               4.0           341.0             0.0          0.0
#
#    num_known_malwares  share_known_malwares
# 0                 0.0                   NaN
# 1                 0.0                   NaN
# 2                 0.0                   NaN
#
# [3 rows x 61 columns]

# %% [markdown]
# #### List of input variables

# %%
with open('../artifacts/variables.json', 'r') as json_file:
    variables = json.load(json_file)

# %% [markdown]
# #### Data schema

# %%
with open('../artifacts/schema.json', 'r') as json_file:
    schema = json.load(json_file)

# %% [markdown]
# <a id='data_und'></a>

# %% [markdown]
# ### Data understanding

# %%
data_und = pd.read_csv('../data/features.csv')

print(f'Shape of data_und: {data_und.shape}.')
print(f'Number of unique instances: {data_und.feature.nunique()}.')

data_und.head(3)
# Out:
# Shape of data_und: (191, 8).
# Number of unique instances: 191.
#     feature    type  n_unique  \
# 0       app  object     22823
# 1   package  object     23485
# 2  category  object        30
#
#                                        sample_values  num_missings  \
# 0  ['Alabama Crimson Tide News' 'Blood Demon Movi...             1
# 1  ['com.estrongs.android.pop.app.shortcut' 'com....             0
# 2  ['Shopping' 'Racing' 'Productivity' 'Sports Ga...             0
#
#    share_missings    var_class        category
# 0        0.000037  categorical  app_attributes
# 1        0.000000  categorical  app_attributes
# 2        0.000000  categorical  app_attributes

# %% [markdown]
# <a id='model_registry'></a>

# %% [markdown]
# ### Model registry

# %%
with open('../artifacts/model_registry.json', 'r') as json_file:
    model_registry = json.load(json_file)

# %% [markdown]
# <a id='artifacts'></a>

# %% [markdown]
# ### Artifacts of the model

# %% [markdown]
# #### Pipeline object

# %%
pipeline = pickle.load(open('../artifacts/pipeline.pickle', 'rb'))

# %% [markdown]
# #### Ensemble object

# %%
ensemble = pickle.load(open('../artifacts/ensemble.pickle', 'rb'))

# %% [markdown]
# <a id='production_model'></a>

# %% [markdown]
# ## Model in production

# %% [markdown]
# <a id='sample_data'></a>

# %% [markdown]
# ### Sample data

# %%
with open('../artifacts/sample_inputs.json', 'r') as json_file:
    sample_inputs = json.load(json_file)

# %% [markdown]
# <a id='model'></a>

# %% [markdown]
# ### Model object

# %%
# Model object from pipeline and ensemble objects:
model = Model(schema=schema, pipeline=pipeline, ensemble=ensemble, variables=variables)

# %%
if EXPORT:
    # Object of fitted pipeline:
    pickle.dump(model, open('../artifacts/model.pickle', 'wb'))

# %% [markdown]
# <a id='predictions'></a>

# %% [markdown]
# ### Predictions from the trained model

# %%
# Object of fitted pipeline:
model = pickle.load(open('../artifacts/model.pickle', 'rb'))

# %%
# Prediction for a given data point:
start = time.time()
prediction = model.predict(input_data=sample_inputs[0],
                           training_data=df_train)
end = time.time()
print(f'Predicted probability that the application is a malware: {prediction[0]:.4f}.')
print(f'Elapsed time: {round(end-start, 2)} seconds.')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
# Predicted probability that the application is a malware: 0.9973.
# Elapsed time: 1.08 seconds.

# %% [markdown]
# #### Evaluating time for prediction

# %%
time_elapsed = []

# Loop over data inputs:
for i in range(len(sample_inputs)):
    # Prediction for a given data point:
    start = time.time()
    prediction = model.predict(input_data=sample_inputs[i],
                              training_data=df_train)
    end = time.time()
    time_elapsed.append(end-start)
  
time_elapsed = pd.DataFrame(data={
    'time_elapsed': time_elapsed
})
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# ...
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.

# %%
display(time_elapsed.time_elapsed.describe())
plot_histogram(
    data=time_elapsed, x=['time_elapsed'], pos=[(1,1)],
    titles=['Distribution of total elapsed time over 1000 samples'], width=700, height=450
)
# Out:
# count    1000.000000
# mean        0.956420
# std         0.051233
# min         0.908056
# 25%         0.941041
# 50%         0.948143
# 75%         0.956907
# max         1.904061
# Name: time_elapsed, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f6e1ff39-38bf-4661-836b-ba6c240e8d80" class="plotly-graph-div" style="height:450px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f6e1ff39-38bf-4661-836b-ba6c240e8d80")) {
#                     Plotly.newPlot(
#                         'f6e1ff39-38bf-4661-836b-ba6c240e8d80',
#                         [{"name": "time_elapsed", "opacity": 0.75, "type": "histogram", "x": [1.0074152946472168, 0.9885828495025635, 1.0202152729034424, 0.9818837642669678, 1.7019753456115723, 1.9040610790252686, 1.4368865489959717, 1.0220575332641602, 0.99472975730896, 0.9980165958404541, 1.0101823806762695, 0.9978611469268799, 0.9872627258300781, 1.0038089752197266, 0.9696249961853027, 0.9823637008666992, 1.1609992980957031, 0.9819104671478271, 1.0091524124145508, 0.9969580173492432, 0.9944026470184326, 1.0072829723358154, 1.0133335590362549, 1.00197434425354, 1.0195095539093018, 1.0004031658172607, 0.9974579811096191, 1.003481149673462, 1.0525729656219482, 0.9875137805938721, 1.0037908554077148, 0.9858682155609131, 0.9850714206695557, 0.9611973762512207, 0.9738662242889404, 0.9978411197662354, 0.9861564636230469, 0.9684178829193115, 0.9583935737609863, 1.0210187435150146, 1.0159189701080322, 0.9851138591766357, 0.9856052398681641, 0.9966533184051514, 0.9835994243621826, 0.964195728302002, 0.9835445880889893, 0.982327938079834, 0.9780185222625732, 0.9675853252410889, 0.9824233055114746, 0.9429295063018799, 0.975745439529419, 0.9837892055511475, 0.9909977912902832, 0.97469162940979, 0.9866619110107422, 0.9636099338531494, 0.9616267681121826, 0.9514727592468262, 0.971287727355957, 0.9540290832519531, 0.9766080379486084, 0.9758529663085938, 0.9608209133148193, 0.9828860759735107, 0.9648489952087402, 0.9566426277160645, 0.9760875701904297, 1.0173242092132568, 1.0110018253326416, 1.0224699974060059, 1.3341403007507324, 1.122450351715088, 0.9898488521575928, 0.968451976776123, 0.9659698009490967, 0.995140790939331, 0.9699521064758301, 0.9321327209472656, 0.9296536445617676, 0.9304566383361816, 0.9317259788513184, 0.9307582378387451, 0.9446556568145752, 0.944993257522583, 0.9432406425476074, 0.9409902095794678, 0.9318532943725586, 0.9525241851806641, 0.944594144821167, 0.9421944618225098, 0.9922428131103516, 0.9561071395874023, 0.9428787231445312, 0.9407162666320801, 0.948155403137207, 0.9319291114807129, 0.9481306076049805, 0.9180581569671631, 0.9482746124267578, 0.9471631050109863, 0.9309096336364746, 0.9529283046722412, 0.9494369029998779, 0.9451088905334473, 0.9366083145141602, 0.928485631942749, 0.9503774642944336, 0.9618752002716064, 0.948084831237793, 0.9203441143035889, 1.0377955436706543, 0.9418976306915283, 0.9439761638641357, 0.9340560436248779, 0.9219284057617188, 0.9475109577178955, 0.9329862594604492, 0.9369485378265381, 0.9204847812652588, 0.935051679611206, 0.9409494400024414, 0.9398641586303711, 0.946488618850708, 0.9396178722381592, 0.9647610187530518, 0.9469120502471924, 0.9330384731292725, 0.942352294921875, 0.9416184425354004, 0.9379398822784424, 0.9339308738708496, 0.9444878101348877, 0.9522073268890381, 0.9614019393920898, 0.9674191474914551, 0.9527132511138916, 0.9631509780883789, 0.9593079090118408, 0.9549133777618408, 0.9547605514526367, 0.9451344013214111, 1.0583765506744385, 0.9315330982208252, 0.9560401439666748, 0.9520561695098877, 0.9478564262390137, 0.9587414264678955, 0.950298547744751, 0.9439191818237305, 0.9442858695983887, 0.945723295211792, 0.9701159000396729, 0.9518439769744873, 0.9475579261779785, 0.9466068744659424, 0.9308507442474365, 0.9549684524536133, 0.9441587924957275, 0.9589922428131104, 0.9630758762359619, 0.9328970909118652, 0.9470124244689941, 0.9520890712738037, 0.986069917678833, 0.9625906944274902, 0.9529592990875244, 0.9620456695556641, 0.9478466510772705, 0.9367456436157227, 0.9505467414855957, 0.9477505683898926, 1.050295352935791, 0.9311089515686035, 0.9458520412445068, 0.9410097599029541, 0.9381270408630371, 0.9439117908477783, 0.9327552318572998, 0.949631929397583, 0.9405972957611084, 0.9418649673461914, 1.2969799041748047, 0.938967227935791, 0.9417099952697754, 0.9393112659454346, 0.9467079639434814, 0.9532256126403809, 0.9406595230102539, 0.9444749355316162, 0.974816083908081, 0.9347374439239502, 0.9438149929046631, 0.9594314098358154, 0.9378461837768555, 0.9423360824584 ...

# %% [markdown]
# #### Handling errors

# %% [markdown]
# Absence of attributes

# %%
missing_attr = deepcopy(sample_inputs[5])
missing_attr.pop('price')
prediction = model.predict(input_data=missing_attr, training_data=df_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-bc51114e2613> in <module>()
#       1 missing_attr = deepcopy(sample_inputs[5])
#       2 missing_attr.pop('price')
# ----> 3 prediction = model.predict(input_data=missing_attr, training_data=df_train)
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in predict(self, input_data, training_data)
#     241
#     242         # Checking the schema:
# --> 243         self.__check_schema(input_data=input_data)
#     244
#     245         if isinstance(input_data, dict):
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in __check_schema(self, input_data)
#     303         missing_vars = [c for c in list(self.schema.keys()) if c not in list(input_data.keys())]
#     304         if len(missing_vars) > 0:
# --> 305             raise ValueError(f'The following variables were not provided: {missing_vars}.')
#     306
#     307         strings = [v for v, t in self.schema.items() if t=='str']
#
# ValueError: The following variables were not provided: ['price'].

# %% [markdown]
# Irrelevant attributes

# %%
irrel_attr = deepcopy(sample_inputs[273])
irrel_attr['price2'] = irrel_attr['price']
prediction = model.predict(input_data=irrel_attr, training_data=df_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning:
#
# Mean of empty slice.

# %%
irrel_attr = deepcopy(sample_inputs[482])
irrel_attr['price2'] = irrel_attr['price']
irrel_attr.pop('price')
irrel_attr.pop('rating')
prediction = model.predict(input_data=irrel_attr, training_data=df_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-35bbc0a58803> in <module>()
#       3 irrel_attr.pop('price')
#       4 irrel_attr.pop('rating')
# ----> 5 prediction = model.predict(input_data=irrel_attr, training_data=df_train)
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in predict(self, input_data, training_data)
#     241
#     242         # Checking the schema:
# --> 243         self.__check_schema(input_data=input_data)
#     244
#     245         if isinstance(input_data, dict):
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in __check_schema(self, input_data)
#     303         missing_vars = [c for c in list(self.schema.keys()) if c not in list(input_data.keys())]
#     304         if len(missing_vars) > 0:
# --> 305             raise ValueError(f'The following variables were not provided: {missing_vars}.')
#     306
#     307         strings = [v for v, t in self.schema.items() if t=='str']
#
# ValueError: The following variables were not provided: ['rating', 'price'].

# %% [markdown]
# Wrong data type

# %%
wrong_type = deepcopy(sample_inputs[61])
wrong_type['rating'] = str(wrong_type['rating'])
prediction = model.predict(input_data=wrong_type, training_data=df_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-97eec93f5647> in <module>()
#       1 wrong_type = deepcopy(sample_inputs[61])
#       2 wrong_type['rating'] = str(wrong_type['rating'])
# ----> 3 prediction = model.predict(input_data=wrong_type, training_data=df_train)
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in predict(self, input_data, training_data)
#     241
#     242         # Checking the schema:
# --> 243         self.__check_schema(input_data=input_data)
#     244
#     245         if isinstance(input_data, dict):
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in __check_schema(self, input_data)
#     316
#     317         if len(wrong_type) > 0:
# --> 318             raise TypeError(f'The following variables have the wrong data type: {wrong_type}.')
#     319
#     320         return
#
# TypeError: The following variables have the wrong data type: ['rating'].

# %%
wrong_type = deepcopy(sample_inputs[119])
wrong_type['category'] = 10
prediction = model.predict(input_data=wrong_type, training_data=df_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-ae2258d78481> in <module>()
#       1 wrong_type = deepcopy(sample_inputs[119])
#       2 wrong_type['category'] = 10
# ----> 3 prediction = model.predict(input_data=wrong_type, training_data=df_train)
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in predict(self, input_data, training_data)
#     241
#     242         # Checking the schema:
# --> 243         self.__check_schema(input_data=input_data)
#     244
#     245         if isinstance(input_data, dict):
#
# /content/gdrive/MyDrive/Studies/end_to_end_ml/src/production.py in __check_schema(self, input_data)
#     316
#     317         if len(wrong_type) > 0:
# --> 318             raise TypeError(f'The following variables have the wrong data type: {wrong_type}.')
#     319
#     320         return
#
# TypeError: The following variables have the wrong data type: ['category'].
